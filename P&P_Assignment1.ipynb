# %% [markdown]
# <a href="https://colab.research.google.com/github/NSteckel/Data-in-Python/blob/main/P%26P_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
file_path = '/content/drive/MyDrive/SkillStorm Files/Pride_and_Prejudice.txt'


myfile = open(file_path, "r", encoding="utf8")
raw_text = myfile.readlines()[36:14229]
print(raw_text)

# %%
formatted = ""

for clean in raw_text:
  if clean!= '\n':
    clean = clean.strip()
    formatted = formatted + str(clean) + " "
formatted = formatted.replace('.', '')
print(formatted)

# %%
countable = formatted.split()
print(str(len(countable)))

# %%
# !pip install nltk

# %%
# !pip install wordcloud

# %%
# !pip install stopwords

# %%
import numpy as np
import pandas as pd
import stopwords
import nltk
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(stopwords = STOPWORDS, background_color=(190,53,25)).generate(formatted)

# %%
plt.figure(figsize = (10, 10))
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
myfile.close()
